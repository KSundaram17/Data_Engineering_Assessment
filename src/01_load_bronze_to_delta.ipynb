# %%
df_jobs = spark.read.option("header", True).csv("/Workspace/Repos/mailsundaramkumari@gmail.com/Data_Engineering_Assessment/exported_bronze/bronze_jobs.csv")
df_jobs.write.format("delta").mode("overwrite").saveAsTable("bronze_jobs")

df_candidates = spark.read.option("header", True).csv("/Workspace/Repos/mailsundaramkumari@gmail.com/Data_Engineering_Assessment/exported_bronze/bronze_candidates.csv")
df_candidates.write.format("delta").mode("overwrite").saveAsTable("bronze_candidates")

df_education = spark.read.option("header", True).csv("/Workspace/Repos/mailsundaramkumari@gmail.com/Data_Engineering_Assessment/exported_bronze/bronze_education.csv")
df_education.write.format("delta").mode("overwrite").saveAsTable("bronze_education")

df_applications = spark.read.option("header", True).csv("/Workspace/Repos/mailsundaramkumari@gmail.com/Data_Engineering_Assessment/exported_bronze/bronze_applications.csv")
df_applications.write.format("delta").mode("overwrite").saveAsTable("bronze_applications")

df_workflow = spark.read.option("header", True).csv("/Workspace/Repos/mailsundaramkumari@gmail.com/Data_Engineering_Assessment/exported_bronze/bronze_workflow_events.csv")
df_workflow.write.format("delta").mode("overwrite").saveAsTable("bronze_workflow_events")

# %%
spark.sql("SELECT COUNT(*) FROM bronze_jobs").show()
spark.sql("SELECT COUNT(*) FROM bronze_candidates").show()
spark.sql("SELECT COUNT(*) FROM bronze_education").show()
spark.sql("SELECT COUNT(*) FROM bronze_applications").show()
spark.sql("SELECT COUNT(*) FROM bronze_workflow_events").show()

# %%
spark.sql("SHOW TABLES").show()
